# %% [markdown]
# # Assignment

# %%
from tkinter import *

# %%
# Q3. 다음은 라디오 버튼 중 어떤 것을 클릭했는지 알려주는 코드입니다. 빈 부분((1),(2),(3))에 들어갈 내용을 채우세요.

from tkinter import *
window=Tk()

def rdo_change():
    if var.get() == 1:
        label1.configure(text="벤츠")
    else:
        lebel1.configure(text="포르쉐")

var = IntVar()
rdo1=Radiobutton(window,text="벤츠",variable= var, value=1,command=rdo_change)
rdo2=Radiobutton(window,text="포르쉐",variable= var, value=2,command=rdo_change)
label1=Label(window,text="선택한 차량",fg="red")

rdo1.pack()
rdo2.pack()
label1.pack()

window.mainloop()

# %%
from IPython.display import Image
Image("./result/3.png")

# %%
# Q4. 코드를 실행하면 다음 각 항에 해당하는 결과가 나오기 위해서 빈 곳에 무엇을 채워야 할지 쓰세요. (빈칸 모두 동일 내용)
#(1)
from tkinter import *
window=Tk()

button1 =Button(window,text="버튼1")
button2 =Button(window,text="버튼2")
button3 =Button(window,text="버튼3")

button1.pack(side= LEFT)
button2.pack(side= LEFT)
button3.pack(side= LEFT)

window.mainloop()

# %%
from IPython.display import Image
Image("./result/4_1.png")

# %%
# Q4. 코드를 실행하면 다음 각 항에 해당하는 결과가 나오기 위해서 빈 곳에 무엇을 채워야 할지 쓰세요. (빈칸 모두 동일 내용)
#(2)
from tkinter import *
window=Tk()

button1 =Button(window,text="버튼1")
button2 =Button(window,text="버튼2")
button3 =Button(window,text="버튼3")

button1.pack(side= RIGHT)
button2.pack(side= RIGHT)
button3.pack(side= RIGHT)

window.mainloop()

# %%
from IPython.display import Image
Image("./result/4_2.png")

# %%
# Q4. 코드를 실행하면 다음 각 항에 해당하는 결과가 나오기 위해서 빈 곳에 무엇을 채워야 할지 쓰세요. (빈칸 모두 동일 내용)
#(3)
from tkinter import *
window=Tk()

button1 =Button(window,text="버튼1")
button2 =Button(window,text="버튼2")
button3 =Button(window,text="버튼3")

button1.pack(side= TOP)
button2.pack(side= TOP)
button3.pack(side= TOP)

window.mainloop()

# %%
from IPython.display import Image
Image("./result/4_3.png")

# %%
# Q4. 코드를 실행하면 다음 각 항에 해당하는 결과가 나오기 위해서 빈 곳에 무엇을 채워야 할지 쓰세요. (빈칸 모두 동일 내용)
#(4)
from tkinter import *
window=Tk()

button1 =Button(window,text="버튼1")
button2 =Button(window,text="버튼2")
button3 =Button(window,text="버튼3")

button1.pack(side= BOTTOM)
button2.pack(side= BOTTOM)
button3.pack(side= BOTTOM)

window.mainloop()

# %%
from IPython.display import Image
Image("./result/4_4.png")

# %%
#5. 다음은 <이전>,<다음> 버튼을 클릭하면 배열(9개 문자열)의 내용으로 글자가 바뀌는 코드입니다. 빈 부분을 채우세요.
#단 마지막 글자에서 <다음>을 클릭하면 다시 첫번째 글자가, 첫번째 글자에서 <이전>을 클릭하면 마지막 글자가 나오도록 하세요.

from tkinter import *
from time import *

fnameList =["jeju1.gif","jeju2.gif","jeju3.gif","jeju4.gif","jeju5.gif","jeju6.gif","jeju7.gif","jeju8.gif","jeju9.gif"]
num = 0

def clickNext():
    global num
    num+=1
    if num>8:
        num=0
    pLabel.configure(text=fnameList[num])
    
def clickPrev():
    global num
    num-=1
    if num <0:
        num=8
    pLabel.configure(text=fnameList[num])

    
window=Tk()
window.geometry("400x100")

window.title("tk")

btnPrev = Button(window, text="<<이전", command=clickPrev)
btnNext = Button(window, text ="다음>>", command= clickNext)
pLabel = Label(window, text=fnameList[num],fg="blue")

btnPrev.place(x=100,y=10)
btnNext.place(x=300,y=10)
pLabel.place(x=200,y=10)

window.mainloop()

# %%
from IPython.display import Image
Image("./result/5.png")

# %% [markdown]
# # Self Study 10-2

# %%
from tkinter import *
import random

# Button and PhotoImage lists
btnList = [None] * 9
fnameList = [
    "sample1.gif", "sample2.gif", "sample3.gif",
    "sample4.gif", "sample5.gif", "sample6.gif",
    "sample7.gif", "sample8.gif", "sample9.gif"
]
photoList = [None] * 9

# Initial positions
xPos, yPos = 0, 0
num = 0

# Main window
window = Tk()
window.geometry("300x300")

# Shuffle the list of file names
random.shuffle(fnameList)

# Load the shuffled images and create buttons
for i in range(9):
    photoList[i] = PhotoImage(file=fnameList[i])
    btnList[i] = Button(window, image=photoList[i])
    btnList[i].image = photoList[i]  # Keep a reference of the image

# Place buttons in a grid
for i in range(3):
    for k in range(3):
        btnList[num].place(x=xPos, y=yPos)
        num += 1
        xPos += 100
    xPos = 0
    yPos += 100

# Run the application
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[35], line 27
#      25 for i in range(9):
#      26     photoList[i] = PhotoImage(file=fnameList[i])
# ---> 27     btnList[i] = Button(window, image=photoList[i])
#      28     btnList[i].image = photoList[i]  # Keep a reference of the image
#      30 # Place buttons in a grid
#
# File ~\anaconda3\Lib\tkinter\__init__.py:2706, in Button.__init__(self, master, cnf, **kw)
#    2687 def __init__(self, master=None, cnf={}, **kw):
#    2688     """Construct a button widget with the parent MASTER.
#    2689
#    2690     STANDARD OPTIONS
#    (...)
#    2704         overrelief, state, width
#    2705     """
# -> 2706     Widget.__init__(self, master, 'button', cnf, kw)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:2628, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2626 for k, v in classes:
# ...

# %%
from IPython.display import Image
Image("./result/selfstudy_random.png")

# %% [markdown]
# # Self Study 10-5

# %%
from tkinter import *
from tkinter.filedialog import *

##함수 선언 부분##
def func_open():
    global photo  # photo를 전역 변수로 선언
    filename=askopenfilename(parent=window, filetypes=(("GIF 파일",".gif"),
                                                       ("모든 파일","*,*")))
    photo=PhotoImage(file=filename)
    #이미지 흑백으로 처리
    for y in range(photo.height()):
        for x in range(photo.width()):
            r,g,b= photo.get(x,y)
            gray = int((r+g+b)/3)
            photo.put("#%02x%02x%02x" % (gray,gray,gray),(x,y))
    pLabel.configure(image=photo)
    pLabel.image =photo

def func_exit():
    window.quit()
    window.destroy()

##============================
window=Tk()
window.geometry("400x400")
window.title("명화 감상하기")

photo =PhotoImage()
pLabel =Label(window,image=photo)
pLabel.pack(expand=1, anchor=CENTER)

mainMenu= Menu(window)
window.config(menu=mainMenu)
fileMenu =Menu(mainMenu)
mainMenu.add_cascade(label="파일", menu=fileMenu)
fileMenu.add_command(label="파일 열기",command=func_open)
fileMenu.add_separator()
fileMenu.add_command(label="프로그램 종료",command=func_exit)

window.mainloop()

# %%
from IPython.display import Image
Image("./result/selfstudy_gray.png")

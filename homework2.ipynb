# %%
#Q1.
print("1 실행후 다른 값을 출력하는 것.")
print("100",100,50+50,"50+50")
print("=====================================")

#Q2.
print("2 다음 코드의 실행 결과를 고르세요.")
print('%d/%d=%d'%(5,10,5/10))
print("=====================================")

#Q3
print("3 다음 코드의 실행 결과를 예상해 보세요.")
print("(1) ","%04d"%876)
print("(2) ","%5s"%"CookBook")
print("(3) ","%1.1f"%123.45)
print("=====================================")

#Q4.
print("4 다음 코드의 실행 결과를 고르세요.")
print("{2:d}{0:d}".format(111,222,333))
print("=====================================")

#Q11.
print("11 다음 각 진수를 모두 10진수로 변환하세요.")
print("(1) 10111(2진수)", int("10111", 2))
print("(2) 1A  (16진수)", int("1A", 16))
print("=====================================")
# Out:
# 1 실행후 다른 값을 출력하는 것.
# 100 100 100 50+50
# ...
# 2 다음 코드의 실행 결과를 고르세요.
# 5/10=0
# ...
# 3 다음 코드의 실행 결과를 예상해 보세요.
# (1)  0876
# (2)  CookBook
# (3)  123.5
# ...
# 4 다음 코드의 실행 결과를 고르세요.
# 333111
# ...
# 11 다음 각 진수를 모두 10진수로 변환하세요.
# (1) 10111(2진수) 23
# (2) 1A  (16진수) 26
# ...

# %%
#Q13.
print("13 오류가 발생하는 것을 모두 고르고, 그 이류를 간단히 설명하세요.")
print("error= int('1002',2)")
print("이유: 2 진수는 0과 1로만 구성")

print("error= int('1008',8)")
print("이유: 8 진수는 0에서 7로만 구성")

print("error= int('AAFG',16)")
print("이유: 0부터 9까지의 숫자와 'A'부터 'F'(또는 소문자 'a'부터 'f')까지의 알파벳으로 구성")
print("=====================================")

#15.
print("15 다음 결과가 나오도록 코드의 빈 곳을 채우세요.")
num=12345678
hex_num=hex(num)
oct_num=oct(num)
bin_num=bin(num)

print(hex(num), oct(num),bin(num))
# Out:
# 13 오류가 발생하는 것을 모두 고르고, 그 이류를 간단히 설명하세요.
# error= int('1002',2)
# 이유: 2 진수는 0과 1로만 구성
# error= int('1008',8)
# 이유: 8 진수는 0에서 7로만 구성
# error= int('AAFG',16)
# 이유: 0부터 9까지의 숫자와 'A'부터 'F'(또는 소문자 'a'부터 'f')까지의 알파벳으로 구성
# ...
# 15 다음 결과가 나오도록 코드의 빈 곳을 채우세요.
# 0xbc614e 0o57060516 0b101111000110000101001110
